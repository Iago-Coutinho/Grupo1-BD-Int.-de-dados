# %%
import pandas as pd

# %%
df = pd.read_csv('../Planilhas/imoveis_unificado.csv', delimiter=';',skiprows=1, encoding='utf-8')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_15356\694419950.py:1: DtypeWarning: Columns (0: numero, 1: ano_construcao, 2: cod_logradouro, 3: latitude, 4: longitude, 5: ano) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../Planilhas/imoveis_unificado.csv', delimiter=';',skiprows=1, encoding='utf-8')

# %%
df.head()
# Out:
#                           logradouro numero complemento valor_avaliacao  \
# 0  av norte miguel arraes de alencar   3071         NaN      1068562.63
# 1  av norte miguel arraes de alencar   3029         NaN      1500000.00
# 2                 rua belmiro correa    133      apto 1       110000.00
# 3                 rua belmiro correa    133      apto 1       110000.00
# 4                 rua belmiro correa    133      apto 2       110000.00
#
#          bairro  cidade  uf ano_construcao area_terreno area_construida  ...  \
# 0  Encruzilhada  Recife  PE           1997        438,0           511,0  ...
# 1  Encruzilhada  Recife  PE           1957       779,33          582,44  ...
# 2  Encruzilhada  Recife  PE           1970       562,05           121,0  ...
# 3  Encruzilhada  Recife  PE           1970       562,05           121,0  ...
# 4  Encruzilhada  Recife  PE           1970       562,05            81,0  ...
#
# ...

# %% [markdown]
# **Tratanto a Coluna Área Construida**

# %% [markdown]
# Criando um variavel para investigar apenas a coluna desejada

# %%
df1 = df['area_construida']
df1.info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 44233 entries, 0 to 44232
# Series name: area_construida
# Non-Null Count  Dtype
# --------------  -----
# 44233 non-null  str
# dtypes: str(1)
# memory usage: 345.7 KB

# %% [markdown]
# Podemos verificar que os dados estão no tipo 'String' quando deveriam estar como 'Float', isso pois representa o valor da área do imóvel.

# %%
df['area_construida'] = df['area_construida'].str.replace(',', '.').astype(float)

# %% [markdown]
# Assim, transformamos o tipo do dados para o correto, como essa coluna não possui valores faltantes, podemos finalizar o tratamento dessa coluna.

# %% [markdown]
# **Tratanto a Coluna Longitude**

# %% [markdown]
# Criando uma variavel para investigar apenas a coluna desejada

# %%
df1 = df['longitude']
df1.info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 44233 entries, 0 to 44232
# Series name: longitude
# Non-Null Count  Dtype
# --------------  -----
# 34980 non-null  object
# dtypes: object(1)
# memory usage: 345.7+ KB

# %% [markdown]
# Podemos verificar que o tipo da coluna longitude não está de acordo com o padrão normalmente usado, que seria o tipo float, assim podemos trocar seu tipo como o código abaixo

# %%
df['longitude'] = df['longitude'].str.replace(',', '.').astype(float)

# %% [markdown]
# Com essa mudança feita, como não possuimos nenhum dados faltante, podemos finalizar o tratamento da coluna longitude
