# %%
import pandas as pd

# %%
df = pd.read_csv('../Planilhas/imoveis_unificado.csv', sep=';', skiprows=1, encoding='utf-8')

# %%
df.head()
# Out:
#                           logradouro  numero complemento valor_avaliacao  \
# 0  av norte miguel arraes de alencar    3071         NaN      1068562.63
# 1  av norte miguel arraes de alencar    3029         NaN      1500000.00
# 2                 rua belmiro correa     133      apto 1       110000.00
# 3                 rua belmiro correa     133      apto 1       110000.00
# 4                 rua belmiro correa     133      apto 2       110000.00
#
#          bairro  cidade  uf  ano_construcao area_terreno area_construida  ...  \
# 0  Encruzilhada  Recife  PE            1997        438,0           511,0  ...
# 1  Encruzilhada  Recife  PE            1957       779,33          582,44  ...
# 2  Encruzilhada  Recife  PE            1970       562,05           121,0  ...
# 3  Encruzilhada  Recife  PE            1970       562,05           121,0  ...
# 4  Encruzilhada  Recife  PE            1970       562,05            81,0  ...
#
#                  tipo_ocupacao data_transacao estado_conservacao  tipo_imovel  \
# 0  COMERCIAL COM LIXO ORGANICO     2023-12-21            Regular       Galpão
# 1  COMERCIAL SEM LIXO ORGANICO     2023-11-17            Regular         Casa
# 2                  RESIDENCIAL     2023-09-22                Bom  Apartamento
# 3                  RESIDENCIAL     2023-09-26                Bom  Apartamento
# 4                  RESIDENCIAL     2023-09-22                Bom  Apartamento
#
#     sfh cod_logradouro  latitude  longitude   ano  Distrito
# 0  0.00          46540 -8.034273 -34.896337  2023       1.0
# 1  0.00          46540 -8.034435 -34.896335  2023       1.0
# 2  0.00          10715 -8.035013 -34.895903  2023       1.0
# 3  0.00          10715 -8.035013 -34.895903  2023       1.0
# 4  0.00          10715 -8.035013 -34.895903  2023       1.0
#
# [5 rows x 23 columns]

# %% [markdown]
# **Tratanto a Coluna Área Construida**

# %% [markdown]
# Criando um variavel para investigar apenas a coluna desejada

# %%
df1 = df['area_construida']
df1.info()
df1.value_counts()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 44231 entries, 0 to 44230
# Series name: area_construida
# Non-Null Count  Dtype
# --------------  -----
# 44231 non-null  str
# dtypes: str(1)
# memory usage: 345.7 KB
# area_construida
# 47,51     263
# 47,52     253
# 76,62     228
# 70,79     227
# 71,57     226
#          ...
# 106,59      1
# 294,31      1
# 53,51       1
# 60,6        1
# 76,13       1
# Name: count, Length: 9379, dtype: int64

# %% [markdown]
# Podemos verificar que os dados estão no tipo 'String' quando deveriam estar como 'Float', isso pois representa o valor da área do imóvel. Além disso, verificamos que os todos os valores são coniventes a serem Area Construidas

# %%
df['area_construida'] = df['area_construida'].str.replace(',', '.').astype(float)

# %% [markdown]
# Assim, transformamos o tipo do dados para o correto, como essa coluna não possui valores faltantes, podemos finalizar o tratamento dessa coluna.

# %% [markdown]
# **Tratanto a Coluna Longitude**

# %% [markdown]
# Criando uma variavel para investigar apenas a coluna desejada

# %%
df1 = df['longitude']
df1.info()
df1.isnull().sum()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 44231 entries, 0 to 44230
# Series name: longitude
# Non-Null Count  Dtype
# --------------  -----
# 29357 non-null  float64
# dtypes: float64(1)
# memory usage: 345.7 KB
# np.int64(14874)

# %% [markdown]
# Podemos verificar que a coluna longitude está com o tipo correto, float, porém está com uma grande quantidade de valores ausentes. Dessa forma, por ja possui outras colunas com informações parecidas, a retirada da coluna é viavel

# %%
df.drop(columns=['longitude'], inplace=True)

# %% [markdown]
# **Tratanto a Coluna padrao_acabamento**

# %% [markdown]
# Criando uma variável para isolar a coluna desejada

# %%
df1 = df['padrao_acabamento']
df1.info()
df1.value_counts()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 44231 entries, 0 to 44230
# Series name: padrao_acabamento
# Non-Null Count  Dtype
# --------------  -----
# 44231 non-null  str
# dtypes: str(1)
# memory usage: 345.7 KB
# padrao_acabamento
# Superior    23087
# Médio       14743
# Simples      6401
# Name: count, dtype: int64

# %% [markdown]
# Verificamos que essa coluna não possui dados faltantes, entranto o tipo está como 'String', nessa situção seria melhor se os dados fossem categoricos, pois o padrão de acabamento so aceita 3 tipos diferentes.

# %%
df['padrao_acabamento'] = df['padrao_acabamento'].astype('category')
df['padrao_acabamento'].dtype
# Out:
# CategoricalDtype(categories=['Médio', 'Simples', 'Superior'], ordered=False, categories_dtype=str)

# %% [markdown]
# Com esse código alteramos o tipo do dado para o correto. Dessa maneira, o tratamento dessa coluna está finalizado
